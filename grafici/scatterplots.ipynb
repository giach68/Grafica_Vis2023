# %% [markdown]
# #  Scatter plots con matplotlib

# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
iris = pd.read_csv("data/iris_csv.csv")

# %%
print(iris)
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.plot(kind="scatter", x="sepallength", y="sepalwidth")
#pandas has integrated plotting functions based on matplotlib
# Out:
# <AxesSubplot: xlabel='sepallength', ylabel='sepalwidth'>

# %%
groups=iris.groupby("class");
labcount=groups.size()
s=labcount.size;
fig, ax = plt.subplots(1, figsize=(10, 6)) #set size of the image
fig.suptitle('Example Of Scatterplot')

for name, group in groups:
    ax.plot(group.sepallength, group.sepalwidth, marker='o', linestyle='', ms=12, label=name)
ax.legend()

#loops. automatically set colors according to sequence

# %%
print(labcount)

labcount.to_dict()
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64
# {'Iris-setosa': 50, 'Iris-versicolor': 50, 'Iris-virginica': 50}

# %%
minVal = iris.min()
print(minVal)
maxVal = iris.max()
print(maxVal)
colors=iris
# Out:
# sepallength            4.3
# sepalwidth             2.0
# petallength            1.0
# petalwidth             0.1
# class          Iris-setosa
# dtype: object
# sepallength               7.9
# sepalwidth                4.4
# petallength               6.9
# petalwidth                2.5
# class          Iris-virginica
# dtype: object

# %%
fig, ax = plt.subplots()
colors = {'Iris-setosa':'red', 'Iris-versicolor':'green', 'Iris-virginica':'blue'}
ax.scatter(iris['petallength'], iris['petalwidth'],c=iris['class'].map(colors))

ax.grid(True)
plt.show()

# %%
fig, ax = plt.subplots()
cols= (iris['sepallength']-minVal['sepallength'])/(maxVal['sepallength']-minVal['sepallength'])
dime= 300*(iris['sepalwidth']-minVal['sepalwidth'])/(maxVal['sepalwidth']-minVal['sepalwidth'])
ax.scatter(iris['petallength'], iris['petalwidth'],dime,cols, cmap='viridis')
sm = plt.cm.ScalarMappable( cmap='viridis', norm=plt.Normalize(vmin=0, vmax=1))
plt.colorbar(sm)
ax.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_45693/3289250358.py:6: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   plt.colorbar(sm)
