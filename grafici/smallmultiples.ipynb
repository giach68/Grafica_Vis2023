# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure()

for i in range(1, 7):
    plt.subplot(3, 2, i)
    plt.title(i)
    plt.xticks([])
    plt.yticks([])

plt.tight_layout()

# %%
dist1 = np.random.normal(42, 7, 1000)
dist2 = np.random.normal(59, 3, 1000)

plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.hist(dist1)
plt.title('dist1')

plt.subplot(1, 2, 2)
plt.scatter(dist2, dist1)
plt.xlabel('dist2')
plt.ylabel('dist1')

plt.tight_layout()

# %% [markdown]
# # Small multiples
#
# ### paradigma di visualizzazione reso popolare da E. Tufte.

# %%
years = np.arange(2010, 2016)

plt.figure()

for category_num in range(1, 17):
    y_vals = np.arange(10, 16) + (np.random.random(6) * category_num / 4.)
    plt.plot(years, y_vals)

plt.ylim(10, 18)
plt.xticks(years, [str(year) for year in years])
# Out:
# ([<matplotlib.axis.XTick at 0x21e7833e1d0>,
#   <matplotlib.axis.XTick at 0x21e7833e710>,
#   <matplotlib.axis.XTick at 0x21e781eda58>,
#   <matplotlib.axis.XTick at 0x21e77f80d68>,
#   <matplotlib.axis.XTick at 0x21e77fae4e0>,
#   <matplotlib.axis.XTick at 0x21e77faea58>],
#  <a list of 6 Text xticklabel objects>)

# %% [markdown]
# ### Stesso grafico ripetuto

# %%
years = np.arange(2010, 2016)

plt.figure(figsize=(10, 10))

for category_num in range(1, 17):
    plt.subplot(4, 4, category_num)
    y_vals = np.arange(10, 16) + (np.random.random(6) * category_num / 4.)
    plt.plot(years, y_vals)
    plt.ylim(10, 18)
    plt.xticks(years, [str(year) for year in years])
    plt.title('Category {}'.format(category_num))
    
plt.tight_layout()
;
# Out:
# ''

# %% [markdown]
# *more complicated layout*

# %% [markdown]
# <img src="indego-bike-station-usage-patterns-july-aug-2015-flip.png" />

# %%
fig = plt.figure(figsize=(8, 8))
gs = plt.GridSpec(3, 3)
ax1 = fig.add_subplot(gs[0, :])
ax2 = fig.add_subplot(gs[1, :2])
ax3 = fig.add_subplot(gs[1:, 2])
ax4 = fig.add_subplot(gs[2, 0])
ax5 = fig.add_subplot(gs[2, 1])
