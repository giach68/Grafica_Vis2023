# %% [markdown]
# # Esempi di grafici con matplotlib
# -------------------------------------------

# %% [markdown]
# Markdown: https://en.wikipedia.org/wiki/Markdown
#
# Si puo' usare la sintassi HTML. Si possono anche **includere** e <em>renderizzare</em> parti in LaTex:
# \begin{equation}
#     JI_{s,i}=\frac{GT_{s,i}\cap P_{s,i}}{GT_{s,i}\cup P_{s,i}}
# \end{equation}

# %% [markdown]
# occorre includere liberie con import. Se non installate provvedere con pip o conda, es. pip install numpy
#  pyplot è l'interfaccia che simula Matlab.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 100)

# %% [markdown]
# **Commonly used parameters**:
#
# * `color`: Set the color of the line.
#
# * `linestyle`: Set the line style, e.g., solid, dashed, or none.
#
# * `linewidth`: Set the line thickness.
#
# * `marker`: Set the marker style, e.g., circles, triangles, or none.
#
# * `markersize`: Set the marker size.
#
# * `label`: Set the label for the line that will show up in the legend.

# %%
plt.plot(x, np.sin(x - 0))        # specify color by name
plt.plot(x, np.sin(x - 1))           # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2))        # Grayscale between 0 and 1

# %%
x = np.linspace(0, 20)
y1 = np.sin(x)
y2 = np.sin(x - np.pi)

plt.figure()

plt.plot(x,
         y1,
         color='black',
         linestyle='-',
         linewidth=2,
         marker='s',
         markersize=6,
         label='y1')

plt.plot(x,
         y2,
         color='gray',
         linestyle='--',
         linewidth=2,
         marker='^',
         markersize=6,
         label='y2')

plt.legend()
;
# Out:
# ''

# %%
plt.plot(x, np.sin(x - 0), color='blue', linestyle='-')  # 'solid' does the same
plt.plot(x, np.sin(x - 1), color='g', linestyle='--') # dashed
plt.plot(x, np.sin(x - 2), color='0.75', linestyle='-.') # dashdot
plt.plot(x, np.sin(x - 3), color='#FFDD44', linestyle=':');  # dotted
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3), linewidth=6,
         linestyle=(0, (5, 2, 1, 2)), dash_capstyle='round')
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported
, linestyle='-')  # solid
# Out:
# ("linestyle='-')", '#', 'solid')

# %% [markdown]
# Si può usare (e si usa generalmente) l'interfaccia Object-Oriented invece di pyplot

# %%
fig, ax1 = plt.subplots()
time = np.linspace(0, 20)
distance = np.sin(x)

ax1.set_ylabel("distance (m)")
ax1.set_xlabel("time")
ax1.plot(time, distance, "blue")

# Add title 
ax1.set_title('My title')

fig.set_size_inches(7,5)
fig.set_dpi(100)

plt.show()

# %% [markdown]
# <h1> Bar charts </h1>

# %%
# create dataset
height = [3, 12, 5, 18, 45]
bars = ('A', 'B', 'C', 'D', 'E')
x_pos = np.arange(len(bars))
 
# Create bars and choose color
plt.bar(x_pos, height, color = (0.5,0.1,0.5,0.6))
 
# Add title and axis names
plt.title('My title')
plt.xlabel('categories')
plt.ylabel('values')
 
# Create names on the x axis
plt.xticks(x_pos, bars)
 
# Show graph
plt.show()

# %%
my_cmap = plt.get_cmap("viridis")
plt.barh(x_pos, height, color=['black', 'red', 'green', 'blue', 'cyan'])
# Out:
# <BarContainer object of 5 artists>

# %%
# voglio usare colormap per categorie distinte https://matplotlib.org/stable/gallery/color/colormap_reference.html
my_cmap = plt.get_cmap("tab10")
plt.bar(x_pos, height, color=my_cmap(x_pos))
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# <h1> pie chart </h1>

# %% [markdown]
# **Commonly used parameters**:
#
# * `colors`: Set the colors of the wedges.
#
# * `labels`: Set the labels of the wedges.
#
# * `startangle`: Set the angle that the wedges start at.
#
# * `autopct`: Set the percentage display format of the wedges.

# %%
print(t_mov)
# Out:
#     Sector  Percentage
# 0   Sci-Fi          20
# 1    Drama          35
# 2   Action          25
# 3   Comedy           5
# 4  Romance          15

# %%
plt.pie(t_mov['Percentage'], 
        labels=t_mov['Sector'])

plt.axis('equal')

plt.show()

# %%
colors = ['darkorange', 'sandybrown', 'darksalmon', 'orangered','chocolate']

plt.pie(t_mov['Percentage'], 
        labels=t_mov['Sector'], 
        colors=colors, 
        autopct='%.2f')

plt.axis('equal')

plt.show()

# %%
explode = (0, 0.1, 0, 0, 0.3)
my_cmap = plt.get_cmap("tab10")
colors=my_cmap(np.linspace(0., 1.,5))

plt.pie(t_mov['Percentage'], 
        labels=t_mov['Sector'], 
        colors=colors, 
        autopct='%.2f',
        explode=explode)

plt.axis('equal')

plt.show()
